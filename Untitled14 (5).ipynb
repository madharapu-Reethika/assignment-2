# %%
import pandas as pd

# %%
car=pd.read_csv('/content/car_purchasing.csv',encoding='latin1')
print(car.describe())
# Out:
#            gender         age  annual Salary  credit card debt  \
# count  500.000000  500.000000     500.000000        500.000000
# mean     0.506000   46.241674   62127.239608       9607.645049
# std      0.500465    7.978862   11703.378228       3489.187973
# min      0.000000   20.000000   20000.000000        100.000000
# 25%      0.000000   40.949969   54391.977195       7397.515792
# 50%      1.000000   46.049901   62915.497035       9655.035568
# 75%      1.000000   51.612263   70117.862005      11798.867487
# max      1.000000   70.000000  100000.000000      20000.000000
#
#             net worth  car purchase amount
# count      500.000000           500.000000
# mean    431475.713625         44209.799218
# std     173536.756340         10773.178744
# min      20000.000000          9000.000000
# 25%     299824.195900         37629.896040
# 50%     426750.120650         43997.783390
# 75%     557324.478725         51254.709517
# max    1000000.000000         80000.000000

# %%
car.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# ...

# %%
car.tail()
# Out:
#     customer name                     customer e-mail      country  gender  \
# 495        Walter                 ligula@Cumsociis.ca        Nepal       0
# 496         Vanna  Cum.sociis.natoque@Sedmolestie.edu     Zimbabwe       1
# 497         Pearl       penatibus.et@massanonante.com  Philippines       1
# 498          Nell   Quisque.varius@arcuVivamussit.net     Botswana       1
# 499         Marla           Camaron.marla@hotmail.com       marlal       1
#
#            age  annual Salary  credit card debt    net worth  \
# 495  41.462515    71942.40291       6995.902524  541670.1016
# 496  37.642000    56039.49793      12301.456790  360419.0988
# 497  53.943497    68888.77805      10611.606860  764531.3203
# 498  59.160509    49811.99062      14013.034510  337826.6382
# 499  46.731152    61370.67766       9391.341628  462946.4924
#
#      car purchase amount
# 495          48901.44342
# 496          31491.41457
# 497          64147.28888
# 498          45442.15353
# ...

# %%
print(car.dtypes)
print("shape",car.shape)
# Out:
# customer name           object
# customer e-mail         object
# country                 object
# gender                   int64
# age                    float64
# annual Salary          float64
# credit card debt       float64
# net worth              float64
# car purchase amount    float64
# dtype: object
# shape (500, 9)

# %%
h = car.drop(['customer name', 'customer e-mail', 'country'], axis=1)
print(h.isnull().sum())
# Out:
# gender                 0
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %%
y=h['car purchase amount']
x=h.drop('car purchase amount',axis=1)
x=x.fillna(0)

# %%
print(x)
print(y)
# Out:
#      gender        age  annual Salary  credit card debt    net worth
# 0         0  41.851720    62812.09301      11609.380910  238961.2505
# 1         0  40.870623    66646.89292       9572.957136  530973.9078
# 2         1  43.152897    53798.55112      11160.355060  638467.1773
# 3         1  58.271369    79370.03798      14426.164850  548599.0524
# 4         1  57.313749    59729.15130       5358.712177  560304.0671
# ..      ...        ...            ...               ...          ...
# 495       0  41.462515    71942.40291       6995.902524  541670.1016
# 496       1  37.642000    56039.49793      12301.456790  360419.0988
# 497       1  53.943497    68888.77805      10611.606860  764531.3203
# 498       1  59.160509    49811.99062      14013.034510  337826.6382
# 499       1  46.731152    61370.67766       9391.341628  462946.4924
#
# [500 rows x 5 columns]
# 0      35321.45877
# 1      45115.52566
# 2      42925.70921
# 3      67422.36313
# 4      55915.46248
#           ...
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
print(x_train.isnull())
print(x_train)
# Out:
#      gender    age  annual Salary  credit card debt  net worth
# 249   False  False          False             False      False
# 433   False  False          False             False      False
# 19    False  False          False             False      False
# 322   False  False          False             False      False
# 332   False  False          False             False      False
# ..      ...    ...            ...               ...        ...
# 106   False  False          False             False      False
# 270   False  False          False             False      False
# 348   False  False          False             False      False
# 435   False  False          False             False      False
# 102   False  False          False             False      False
#
# [400 rows x 5 columns]
#      gender        age  annual Salary  credit card debt    net worth
# 249       0  36.117247    70334.42787       9823.218967  632600.4718
# ...

# %%
print(x_test)
print(y_train)
# Out:
#      gender        age  annual Salary  credit card debt    net worth
# 361       0  36.126918    74420.10254      10274.135580  551344.3365
# 73        1  47.789729    59139.21080       4630.544424  473845.8546
# 374       1  57.134576    67752.38329      13851.921220  657178.4135
# 155       0  50.219573    55381.53225       5088.239017   20000.0000
# 104       0  48.476396    63975.06090      10614.854490  891439.8761
# ..      ...        ...            ...               ...          ...
# 347       0  46.911891    56692.78044       7946.435929  685541.6501
# 86        1  44.486915    63087.95261      11024.026430  496856.4912
# 75        0  46.960781    69157.45210      15791.611760  506986.9824
# 438       0  44.277419    70230.15498       8542.019129  320525.7282
# 15        1  53.289768    64662.30061      11326.034340  481433.4324
#
# [100 rows x 5 columns]
# 249    46135.27233
# 433    29519.56184
# 19     54827.52403
# 322    59625.02618
# 332    25252.93221
#           ...
# ...

# %%
print(y_test)
# Out:
# 361    46082.80993
# 73     45058.89690
# 374    63079.84329
# 155    31837.22537
# 104    60461.24268
#           ...
# 347    49079.29461
# 86     45167.32542
# 75     50958.08115
# 438    43898.27330
# 15     53017.26723
# Name: car purchase amount, Length: 100, dtype: float64

# %%
#graphs between features and target variable

# %%
import matplotlib.pyplot as plt
plt.scatter(car['age'], car['car purchase amount'])
plt.xlabel('Age')
plt.ylabel('Car Purchase Amount')
plt.title(' Age vs Car Purchase Amount')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(car['gender'], car['car purchase amount'])
plt.xlabel('gender')
plt.ylabel('Car Purchase Amount')
plt.title(' gender vs Car Purchase Amount')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(car['annual Salary'], car['car purchase amount'])
plt.xlabel('annual Salary')
plt.ylabel('Car Purchase Amount')
plt.title(' annual Salaryvs Car Purchase Amount')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(car['net worth'], car['car purchase amount'])
plt.xlabel(' net worth')
plt.ylabel('Car Purchase Amount')
plt.title(' net worth vs Car Purchase Amount')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np


linear_model = LinearRegression()
linear_model.fit(X_train_scaled, y_train)


y_pred_linear = linear_model.predict(X_test_scaled)


scaling_factor = 0.1


y_pred_linear_modified = y_pred_linear * scaling_factor


mse_linear_modified = mean_squared_error(y_test, y_pred_linear_modified)
mae_linear_modified = mean_absolute_error(y_test, y_pred_linear_modified)
rmse_linear_modified = np.sqrt(mse_linear_modified)


print("Mean Squared Error:", mse_linear_modified)
print("Mean Absolute Error:", mae_linear_modified)
print("Root Mean Squared Error:", rmse_linear_modified)
# Out:
# Mean Squared Error: 1747061761.1378946
# Mean Absolute Error: 40738.23251092467
# Root Mean Squared Error: 41797.867901818805

# %%
import matplotlib.pyplot as plt
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs. Actual Values')
plt.show()

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

knn_model = KNeighborsRegressor(n_neighbors=5)
knn_model.fit(X_train_scaled, y_train)
y_pred = knn_model.predict(X_test_scaled)
mse = mean_squared_error(y_test, y_pred)
print("Mean squared Error:",mse)
knn_model = KNeighborsRegressor(n_neighbors=5)
knn_model.fit(X_train_scaled, y_train)
y_pred = knn_model.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", rmse)
# Out:
# Mean squared Error: 13191565.563198535
# Mean Absolute Error: 2845.638711
# Root Mean Squared Error: 3632.0194882735054

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], linestyle='--', color='red', linewidth=2)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted for knn')
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
tree_model = DecisionTreeRegressor()
tree_model.fit(X_train_scaled, y_train)
y_pred = tree_model.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
rmse = np.sqrt(mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Absolute Error: 2749.6864269000002
# Mean Squared Error: 12732559.662782207
# Root Mean Squared Error: 3568.271242882498

# %%
import matplotlib.pyplot as plt

# Plot actual vs. predicted values
plt.figure(figsize=(6, 5))
plt.scatter(y_test, y_pred, color='blue', label='Actual vs. Predicted')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], '--', color='red', label='Perfect Prediction')
plt.title('Actual vs. Predicted Values for Decision Tree Regression')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.show()

# %%
import pandas as pd
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error

svm_model = SVR()
svm_model.fit(X_train_scaled, y_train)

y_pred = svm_model.predict(X_test_scaled)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)

print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("Root Mean Square Error:", rmse)
# Out:
# Mean Squared Error: 109624906.46186401
# Mean Absolute Error: 8418.546282827978
# Root Mean Square Error: 10470.191328808849

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(9, 5))
plt.scatter(y_test, y_pred, color='blue', label='Actual vs. Predicted')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], '--', color='red', label='Perfect Prediction')
plt.title('Actual vs. Predicted Values for SVM Regression')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error


rf_regressor = RandomForestRegressor()
ab_regressor = AdaBoostRegressor()


rf_regressor.fit(x_train, y_train)
ab_regressor.fit(x_train, y_train)


rf_pred = rf_regressor.predict(x_test)
ab_pred = ab_regressor.predict(x_test)


rf_mse = mean_squared_error(y_test, rf_pred)
rf_mae = mean_absolute_error(y_test, rf_pred)
rf_rmse = mean_squared_error(y_test, rf_pred, squared=False)

ab_mse = mean_squared_error(y_test, ab_pred)
ab_mae = mean_absolute_error(y_test, ab_pred)
ab_rmse = mean_squared_error(y_test, ab_pred, squared=False)


print("RandomForest Regressor:")
print("Mean Squared Error:", rf_mse)
print("Mean Absolute Error:", rf_mae)
print("Root Mean Square Error:", rf_rmse)
print("\nAdaBoost Regressor:")
print("Mean Squared Error:", ab_mse)
print("Mean Absolute Error:", ab_mae)
print("Root Mean Square Error:", ab_rmse)
# Out:
# RandomForest Regressor:
# Mean Squared Error: 4934151.479672898
# Mean Absolute Error: 1567.5347696609963
# Root Mean Square Error: 2221.2950005960256
#
# AdaBoost Regressor:
# Mean Squared Error: 11253332.430287149
# Mean Absolute Error: 2382.217623418991
# Root Mean Square Error: 3354.5986988441923

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 5))
plt.scatter(y_test, rf_pred, color='blue', label='RandomForest')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('RandomForestRegressor: Actual vs Predicted')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.scatter(y_test, ab_pred, color='green', label='AdaBoost')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('AdaBoostRegressor: Actual vs Predicted ')
plt.legend()
plt.show()
